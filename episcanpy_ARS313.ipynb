# %%
import episcanpy as epi
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load count_matrix
load_dir= "ARS313"

wt_rep3 = np.loadtxt(load_dir + "/wt_mat_Megalodon_repIII_ARS313_end_LexA.txt")

# %%
features = epi.ct.load_features(load_dir + "/ARS313_testbed.bed") # generate features
p_names = epi.ct.name_features(features) # extract name of the features - produce unique

# %%
adata = ad.AnnData(wt_rep3, dtype = wt_rep3.dtype) #, var = pd.DataFrame(index=p_names))

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 780 × 1033

# %%
epi.pp.lazy(adata)

# %%
sc.pl.pca(adata)

# %%
sc.pl.umap(adata)

# %%
sc.tl.leiden(adata, resolution= 0.3)

# %%
sc.pl.umap(adata, color="leiden")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 780 × 1033
#     obs: 'leiden'
#     uns: 'pca', 'neighbors', 'tsne', 'umap', 'leiden', 'leiden_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
epi.tl.dendogram(adata, groupby="leiden")

# %%
epi.tl.kmeans(adata, num_clusters= 3)
adata
# Out:
# AnnData object with n_obs × n_vars = 780 × 1033
#     obs: 'leiden', 'kmeans'
#     uns: 'pca', 'neighbors', 'tsne', 'umap', 'leiden', 'leiden_colors', 'dendrogram_leiden', 'kmeans_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata, color="kmeans")
